# %%
import pandas as pd

# %%
flights = pd.read_csv("data/nycflights13.csv")
flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 2       2013      1    1     542.0             540        2.0     923.0
# 3       2013      1    1     544.0             545       -1.0    1004.0
# 4       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336771  2013      9   30       NaN            1455        NaN       NaN
# 336772  2013      9   30       NaN            2200        NaN       NaN
# 336773  2013      9   30       NaN            1210        NaN       NaN
# 336774  2013      9   30       NaN            1159        NaN       NaN
# 336775  2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
flights.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# ...

# %%
mpg = pd.read_csv("data/mpg.csv")

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %%
diamonds = pd.read_csv("data/diamonds.csv")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
mass_schools = pd.read_csv("data/massachusetts public schools/MA_Public_Schools_2017.csv")

# %%
mass_schools.head()
# Out:
#    School Code                     School Name    School Type   Function  \
# 0        10505                   Abington High  Public School  Principal
# 1        10003  Beaver Brook Elementary School  Public School  Principal
# 2        10002        Center Elementary School  Public School  Principal
# 3        10405            Frolio Middle School  Public School  Principal
# 4        10015     Woodsdale Elementary School  Public School  Principal
#
#            Contact Name            Address 1 Address 2      Town State   Zip  \
# 0  Teresa Sullivan-Cruz   201 Gliniewicz Way       NaN  Abington    MA  2351
# 1       Catherine Zinni  1 Ralph Hamlin Lane       NaN  Abington    MA  2351
# 2        Lora Monachino   201 Gliniewicz Way       NaN  Abington    MA  2351
# 3    Matthew MacCurtain   201 Gliniewicz Way       NaN  Abington    MA  2351
# 4        Jonathan Hawes  128 Chestnut Street       NaN  Abington    MA  2351
#
#    ... MCAS_10thGrade_English_Incl. in SGP(#)  \
# ...

# %%
fast_food = pd.read_csv("data/fastfood_calories.txt")

# %%
fast_food.head()
# Out:
#    Unnamed: 0 restaurant                                       item  calories  \
# 0           1  Mcdonalds           Artisan Grilled Chicken Sandwich       380
# 1           2  Mcdonalds             Single Bacon Smokehouse Burger       840
# 2           3  Mcdonalds             Double Bacon Smokehouse Burger      1130
# 3           4  Mcdonalds  Grilled Bacon Smokehouse Chicken Sandwich       750
# 4           5  Mcdonalds   Crispy Bacon Smokehouse Chicken Sandwich       920
#
#    cal_fat  total_fat  sat_fat  trans_fat  cholesterol  sodium  total_carb  \
# 0       60          7      2.0        0.0           95    1110          44
# 1      410         45     17.0        1.5          130    1580          62
# 2      600         67     27.0        3.0          220    1920          63
# 3      280         31     10.0        0.5          155    1940          62
# 4      410         45     12.0        0.5          120    1980          81
#
# ...

# %%
college_majors = pd.read_csv("data/college-majors.csv")

# %%
college_majors.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
restaurants = pd.read_csv("data/nyc_restaurants.csv")

# %%
restaurants.head()
# Out:
#       camis                           dba      boro  zipcode  \
# 0  50039667                    WIDDI HALL  BROOKLYN  11220.0
# 1  41638047       BESO RESTAURANT AND BAR  BROOKLYN  11233.0
# 2  41629883                 CAFE MADELINE  BROOKLYN  11226.0
# 3  50032889  SHUN YUEN CHINESE RESTAURANT     BRONX  10458.0
# 4  41655832               BIA BAR & GRILL  BROOKLYN  11249.0
#
#                                  cuisine_description inspection_date  \
# 0                                     Middle Eastern      06/02/2016
# 1  Latin (Cuban, Dominican, Puerto Rican, South &...      10/26/2016
# 2                                   CafÃ©/Coffee/Tea      05/15/2017
# 3                                            Chinese      03/29/2018
# 4                      Vietnamese/Cambodian/Malaysia      05/02/2018
#
#                                               action violation_code  \
# 0    Violations were cited in the following area(s).            10F
# ...

# %%
[column for column in restaurants.columns]
# Out:
# ['camis',
#  'dba',
#  'boro',
#  'zipcode',
#  'cuisine_description',
#  'inspection_date',
#  'action',
#  'violation_code',
#  'violation_description',
#  'critical_flag',
#  'score',
#  'grade',
#  'inspection_type']

# %%
restaurants.head()
# Out:
#       camis                           dba      boro  zipcode  \
# 0  50039667                    WIDDI HALL  BROOKLYN  11220.0
# 1  41638047       BESO RESTAURANT AND BAR  BROOKLYN  11233.0
# 2  41629883                 CAFE MADELINE  BROOKLYN  11226.0
# 3  50032889  SHUN YUEN CHINESE RESTAURANT     BRONX  10458.0
# 4  41655832               BIA BAR & GRILL  BROOKLYN  11249.0
#
#                                  cuisine_description inspection_date  \
# 0                                     Middle Eastern      06/02/2016
# 1  Latin (Cuban, Dominican, Puerto Rican, South &...      10/26/2016
# 2                                   CafÃ©/Coffee/Tea      05/15/2017
# 3                                            Chinese      03/29/2018
# 4                      Vietnamese/Cambodian/Malaysia      05/02/2018
#
#                                               action violation_code  \
# 0    Violations were cited in the following area(s).            10F
# ...

# %%
restaurants = None

# %%
restaurants = pd.read_csv("https://github.com/briandk/2020-virtual-program-in-data-science/raw/master/data/nyc_restaurants.csv")

# %%
restaurants.head()
# Out:
#       camis                           dba      boro  zipcode  \
# 0  50039667                    WIDDI HALL  BROOKLYN  11220.0
# 1  41638047       BESO RESTAURANT AND BAR  BROOKLYN  11233.0
# 2  41629883                 CAFE MADELINE  BROOKLYN  11226.0
# 3  50032889  SHUN YUEN CHINESE RESTAURANT     BRONX  10458.0
# 4  41655832               BIA BAR & GRILL  BROOKLYN  11249.0
#
#                                  cuisine_description inspection_date  \
# 0                                     Middle Eastern      06/02/2016
# 1  Latin (Cuban, Dominican, Puerto Rican, South &...      10/26/2016
# 2                                   CafÃ©/Coffee/Tea      05/15/2017
# 3                                            Chinese      03/29/2018
# 4                      Vietnamese/Cambodian/Malaysia      05/02/2018
#
#                                               action violation_code  \
# 0    Violations were cited in the following area(s).            10F
# ...

# %%
incarceration = pd.read_csv("data/incarceration_trends.csv")

# %%
incarceration.tail()
# Out:
#             yfips  year   fips state    county_name  total_pop  \
# 147528  201256045  2012  56045    WY  Weston County       7141
# 147529  201356045  2013  56045    WY  Weston County       7074
# 147530  201456045  2014  56045    WY  Weston County       7136
# 147531  201556045  2015  56045    WY  Weston County       7142
# 147532  201656045  2016  56045    WY  Weston County       7181
#
#         total_pop_15to64  female_pop_15to64  male_pop_15to64  \
# 147528              4662               2098             2564
# 147529              4584               2055             2529
# 147530              4624               2084             2540
# 147531              4611               2066             2545
# 147532              4601               2063             2538
#
#         asian_pop_15to64  ...  violent_crime  property_crime  murder_crime  \
# 147528              17.0  ...            5.0            91.0           0.0
# ...

# %%
myData = pd.DataFrame({"x": ["1756e8"]}, index = [1])

# %%
myData
# Out:
#         x
# 1  1756e8

# %%
pd.to_numeric(myData["x"])
# Out:
# 1    1.756000e+11
# Name: x, dtype: float64

# %%
r_and_d = pd.read_csv("data/federal_r_and_d_spending/fed_r_d_spending.csv")

# %%
r_and_d.head()
# Out:
#   department  year     rd_budget  total_outlays  discretionary_outlays  \
# 0        DOD  1976  3.569600e+10   3.718000e+11           1.756000e+11
# 1       NASA  1976  1.251300e+10   3.718000e+11           1.756000e+11
# 2        DOE  1976  1.088200e+10   3.718000e+11           1.756000e+11
# 3        HHS  1976  9.226000e+09   3.718000e+11           1.756000e+11
# 4        NIH  1976  8.025000e+09   3.718000e+11           1.756000e+11
#
#             gdp
# 0  1.790000e+12
# 1  1.790000e+12
# 2  1.790000e+12
# 3  1.790000e+12
# 4  1.790000e+12

# %%
r_and_d[["rd_budget", "total_outlays", "discretionary_outlays", "gdp"]].describe()
# Out:
#           rd_budget  total_outlays  discretionary_outlays           gdp
# count  5.880000e+02   5.880000e+02           5.880000e+02  5.880000e+02
# mean   1.035362e+10   1.880493e+12           6.941619e+11  9.175119e+12
# std    1.786595e+10   1.103720e+12           3.601908e+11  5.217163e+12
# min    0.000000e+00   3.718000e+11           1.756000e+11  1.790000e+12
# 25%    9.020000e+08   9.904000e+11           4.385000e+11  4.536000e+12
# 50%    1.888500e+09   1.580800e+12           5.459500e+11  8.230500e+12
# 75%    1.205800e+10   2.728700e+12           1.041600e+12  1.432300e+13
# max    9.432500e+10   3.981600e+12           1.347200e+12  1.917700e+13

# %%
phds_by_field = pd.read_csv("data/phd_by_field.csv")

# %%
phds_by_field.head()
# Out:
#      broad_field                                  major_field  \
# 0  Life sciences  Agricultural sciences and natural resources
# 1  Life sciences  Agricultural sciences and natural resources
# 2  Life sciences  Agricultural sciences and natural resources
# 3  Life sciences  Agricultural sciences and natural resources
# 4  Life sciences  Agricultural sciences and natural resources
#
#                                            field  year  n_phds
# 0                         Agricultural economics  2008   111.0
# 1  Agricultural and horticultural plant breeding  2008    28.0
# 2                   Agricultural animal breeding  2008     3.0
# 3                      Agronomy and crop science  2008    68.0
# 4                               Animal nutrition  2008    41.0

# %%
jobs_gender = pd.read_csv("data/jobs_gender.csv")

# %%
jobs_gender.head()
# Out:
#    year                           occupation  \
# 0  2013                     Chief executives
# 1  2013      General and operations managers
# 2  2013                          Legislators
# 3  2013  Advertising and promotions managers
# 4  2013         Marketing and sales managers
#
#                         major_category minor_category  total_workers  \
# 0  Management, Business, and Financial     Management        1024259
# 1  Management, Business, and Financial     Management         977284
# 2  Management, Business, and Financial     Management          14815
# 3  Management, Business, and Financial     Management          43015
# 4  Management, Business, and Financial     Management         754514
#
#    workers_male  workers_female  percent_female  total_earnings  \
# 0        782400          241859            23.6          120254
# 1        681627          295657            30.3           73557
# 2          8375            6440            43.5           67155
# ...

# %%
jobs_gender.tail()
# Out:
#       year                                 occupation  \
# 2083  2016                  Pumping station operators
# 2084  2016  Refuse and recyclable material collectors
# 2085  2016                 Mine shuttle car operators
# 2086  2016          Tank car, truck, and ship loaders
# 2087  2016         Material moving workers, all other
#
#                                        major_category   minor_category  \
# 2083  Production, Transportation, and Material Moving  Material Moving
# 2084  Production, Transportation, and Material Moving  Material Moving
# 2085  Production, Transportation, and Material Moving  Material Moving
# 2086  Production, Transportation, and Material Moving  Material Moving
# 2087  Production, Transportation, and Material Moving  Material Moving
#
#       total_workers  workers_male  workers_female  percent_female  \
# 2083          19540         18917             623        3.188332
# 2084          65170         58851            6319        9.696179
# ...

# %%
nobel_winners = pd.read_csv("data/nobel_winners.csv")

# %%
nobel_winners.tail()
# Out:
#      prize_year  category                                           prize  \
# 964        2016  Medicine  The Nobel Prize in Physiology or Medicine 2016
# 965        2016     Peace                      The Nobel Peace Prize 2016
# 966        2016   Physics                 The Nobel Prize in Physics 2016
# 967        2016   Physics                 The Nobel Prize in Physics 2016
# 968        2016   Physics                 The Nobel Prize in Physics 2016
#
#                                             motivation prize_share  \
# 964  "for his discoveries of mechanisms for autophagy"         1/1
# 965  "for his resolute efforts to bring the country...         1/1
# 966  "for theoretical discoveries of topological ph...         1/2
# 967  "for theoretical discoveries of topological ph...         1/4
# 968  "for theoretical discoveries of topological ph...         1/4
#
#      laureate_id laureate_type              full_name  birth_date birth_city  \
# ...

# %%
ufo_sightings = pd.read_csv("data/ufo_sightings.csv")

# %%
ufo_sightings.tail()
# Out:
#             date_time  city_area state country ufo_shape  encounter_length  \
# 80327  9/9/2013 21:15  nashville    tn      us     light             600.0
# 80328  9/9/2013 22:00      boise    id      us    circle            1200.0
# 80329  9/9/2013 22:00       napa    ca      us     other            1200.0
# 80330  9/9/2013 22:20     vienna    va      us    circle               5.0
# 80331  9/9/2013 23:00     edmond    ok      us     cigar            1020.0
#
#       described_encounter_length  \
# 80327                 10 minutes
# 80328                 20 minutes
# 80329                       hour
# 80330                  5 seconds
# 80331                 17 minutes
#
#                                              description date_documented  \
# 80327  Round from the distance/slowly changing colors...       9/30/2013
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...       9/30/2013
# 80329                                       Napa UFO&#44       9/30/2013
# ...

# %%
video_games = pd.read_csv("data/video_games.csv")

# %%
video_games.tail()
# Out:
#        number                           game  release_date  price  \
# 26683    8842                      Draw Near  Apr 15, 2018    NaN
# 26684    8843                          Alone   May 1, 2018   0.99
# 26685    8844                      qrth-phyl  Jul 19, 2018   4.99
# 26686    8845                 Guns and Notes  Jan 26, 2018   9.99
# 26687    8846  VANILLA - GARDEN OF JUDGEMENT  Aug 10, 2018  14.99
#
#             owners               developer           publisher  \
# 26683  0 .. 20,000             Omniscience     Taiga Nishimura
# 26684  0 .. 20,000      Killed Pixel Games  Killed Pixel Games
# 26685  0 .. 20,000                  Verran              Verran
# 26686  0 .. 20,000              VR Factory          VR Factory
# 26687  0 .. 20,000  CHARON, Kaoru Nekofuji              CHARON
#
#        average_playtime  median_playtime  metascore
# 26683               0.0              0.0        NaN
# 26684               0.0              0.0        NaN
# ...
